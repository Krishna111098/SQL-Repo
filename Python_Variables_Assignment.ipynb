# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishna111098/SQL-Repo/blob/main/Python_Variables_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Variables Practice (Assignment 1)
#
# **Topics Covered:**
# - Variable creation
# - int, float, str, bool data types
# - Printing variables
# - f-strings

# %% [markdown]
# ## Section 1: Variable Creation & Printing

# %% [markdown]
# ### Question 1
# Create a variable to store your **age** and print it.

# %%
# write your answer

age =input("Enter Your Age")

print(age)
# Out:
# Enter Your Age35
# 35

# %% [markdown]
# ### Question 2
# Create a variable to store the **price of a notebook** (can be a decimal value) and print it.

# %%
# write your answer
price = float(input("Enter price of Notebook"))
print(price)
# Out:
# Enter price of Notebook32.8
# 32.8

# %% [markdown]
# ### Question 3
# Create a variable to store your **first name** and print it.

# %%
# write your answer

name = input("Enter uour name")
print(name)
# Out:
# Enter uour nameKrishna
# Krishna

# %% [markdown]
# ### Question 4
# Create a variable to store whether you have **completed today’s class** (True/False) and print it.

# %%
# write your answer
attendance = input("True/False")
print(attendance)
# Out:
# True/Falsetrue
# true

# %% [markdown]
# ### Question 5
# Create two variables:
# - one to store the **number of classes attended**
# - one to store the **average rating** (float)
# Print both.

# %%
# write your answer
classes_attend = input("Enter Number of classes you have attended ")
rating = input("Average Rating")
print(classes_attend)
print(rating)
# Out:
# Enter Number of classes you have attended 5
# Average Rating8
# 5
# 8

# %% [markdown]
# ## Section 2: Printing using f-strings

# %% [markdown]
# ### Question 6
# Create variables for **name** and **age** and print:
# > My name is Rahul and I am 22 years old.

# %%
# write your answer
name = input("Enter Your Name")
age= int(input("Enter your age "))
print(f"My name is {name} and I am {age} years old.")
# Out:
# Enter Your NameRahul
# Enter your age 22
# My name is Rahul and I am 22 years old.

# %% [markdown]
# ### Question 7
# Create variables for **item name** and **price** and print:
# > The price of Pen is 10.5 rupees.

# %%
# write your answer
item = input("Enter name of the item ")
price = float(input("Enter item's price"))
print(f"The price of {item} is {price} rupees")
# Out:
# Enter name of the item Pen
# Enter item's price32.5
# The price of Pen is 32.5 rupees

# %% [markdown]
# ### Question 8
# Create variables for **batch name** and **class completed status** and print:
# > Batch DA10 class completed status is True.

# %%
# write your answer
Batch = input("Enter your Batch Name ")
Class_stat = input("Class is completed : True / False ")
print(f"Batch {Batch} class completed status is {Class_stat}.")
# Out:
# Enter your Batch Name DA10
# Class is completed : True / False True
# Batch DA10 class completed status is True.
